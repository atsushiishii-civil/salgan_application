# %% [markdown]
# ## SALGAN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1. create the foler named "data" and saved "images" and "graymaps" folder in it.
#2. run below

# %%
# !python main.py --dataset_dir data/
